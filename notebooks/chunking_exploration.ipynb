# %% [markdown]
# # Chunking Exploration
#
# Explore PDF chunk boundaries, overlap sizes, and metadata coverage.
# Use this to verify your chunker implementation is correct.

# %%
# TODO: YOU implement this notebook
- Load chunks from vector store
- Analyze chunk sizes, overlaps, law number distribution
- Visualize chunk hierarchy
- Spot-check for missing laws
